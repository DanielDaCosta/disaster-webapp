# %%
import pandas as pd
import re
from sqlalchemy import create_engine
import nltk
from nltk.corpus import stopwords
from nltk.stem.wordnet import WordNetLemmatizer
from nltk.tokenize import word_tokenize
from sklearn.pipeline import Pipeline, FeatureUnion
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.multioutput import MultiOutputClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, accuracy_score

# %% [markdown]
# ### Import libraries and load data from database.

# %%
# load data from database
engine = create_engine('sqlite:///data/DisasterResponse.db')

# %%
df = pd.read_sql_table('messages', engine)

# %% [markdown]
# ### Data Preparation

# %% [markdown]
# '@' mention. Even tough @ adds some information to the message, this information doesn't add value build the classifcation model

# %%
df['message_clean'] = df.message.apply(lambda x: re.sub(r'@[A-Za-z0-9_]+','',str(x)))

# %% [markdown]
# Dealing with URL links

# %%
url_regex = 'http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\(\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+'
df['message_clean'] = df.message_clean.apply(lambda x: re.sub(url_regex,'urlplaceholder',str(x)))

# %%
# A log of url are write as follows: http bit.ly. Apply Regex for these cases
utl_regex_2 = 'http [a-zA-Z]+\.[a-zA-Z]+'
df['message_clean'] = df.message_clean.apply(lambda x: re.sub(utl_regex_2,'urlplaceholder',str(x)))

# %%
# Other formats: http : //t.co/ihW64e8Z
utl_regex_3 = 'http \: //[a-zA-Z]\.(co|com|pt|ly)/[A-Za-z0-9_]+'

# %%
df['message_clean'] = df.message_clean.apply(lambda x: re.sub(utl_regex_3,'urlplaceholder',str(x)))

# %% [markdown]
# Hashtags can provide useful informations. Removing only ``#``

# %%
df['message_clean'] = df.message_clean.apply(lambda x: re.sub('#',' ',str(x)))

# %%
re.sub('#', ' ', test)
# Out:
# "New Yorkers : Come volunteer w/ us on LES at 46 Hestor 10 AM . Delivering meds to elderly still in highrises being flashlight .  SandyHelp' "

# %%
stop_words = stopwords.words("english")
lemmatizer = WordNetLemmatizer()

# %%
def tokenize(text):
    # '@' mention. Even tough @ adds some information to the message, 
    # this information doesn't add value build the classifcation model
    text = re.sub(r'@[A-Za-z0-9_]+','', text)
    
    # Dealing with URL links
    url_regex = 'http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\(\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+'
    text = re.sub(url_regex,'urlplaceholder', text)
    # A lot of url are write as follows: http bit.ly. Apply Regex for these cases
    text = re.sub(utl_regex_2,'urlplaceholder', text)
    # Other formats: http : //t.co/ihW64e8Z
    utl_regex_3 = 'http \: //[a-zA-Z]\.(co|com|pt|ly)/[A-Za-z0-9_]+'
    text = re.sub(utl_regex_3,'urlplaceholder', text)
    
    # Hashtags can provide useful informations. Removing only ``#``
    text = re.sub('#',' ', text)
    
    text = text.lower()
    # Ponctuation Removal
    text = re.sub(r'[^a-zA-Z0-9]', ' ', text)
    tokens = word_tokenize(text)
    tokens = [lemmatizer.lemmatize(w) for w in tokens]
    tokens = [tok for tok in tokens if tok not in stop_words]
    return tokens

# %%
output_columns = ['related', 'request', 'offer', 'aid_related',
       'medical_help', 'medical_products', 'search_and_rescue', 'security',
       'military', 'child_alone', 'water', 'food', 'shelter', 'clothing',
       'money', 'missing_people', 'refugees', 'death', 'other_aid',
       'infrastructure_related', 'transport', 'buildings', 'electricity',
       'tools', 'hospitals', 'shops', 'aid_centers', 'other_infrastructure',
       'weather_related', 'floods', 'storm', 'fire', 'earthquake', 'cold',
       'other_weather', 'direct_report']

# %%
X = df['message']
y = df[output_columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state = 42)

# %%
def build_model():
    pipeline = Pipeline([
        ('vect', CountVectorizer(tokenizer=tokenize)),
        ('tfidf', TfidfTransformer()),
        ('clf', MultiOutputClassifier(RandomForestClassifier()))
    ])
    
    return pipeline

# %%
pipe = build_model()

# %%
pipe.fit(X_train, y_train)
# Out:
# Pipeline(memory=None,
#          steps=[('vect',
#                  CountVectorizer(analyzer='word', binary=False,
#                                  decode_error='strict',
#                                  dtype=<class 'numpy.int64'>, encoding='utf-8',
#                                  input='content', lowercase=True, max_df=1.0,
#                                  max_features=None, min_df=1,
#                                  ngram_range=(1, 1), preprocessor=None,
#                                  stop_words=None, strip_accents=None,
#                                  token_pattern='(?u)\\b\\w\\w+\\b',
#                                  tokenizer=<function tokenize at...
#                                                                         ccp_alpha=0.0,
#                                                                         class_weight=None,
#                                                                         criterion='gini',
#                                                                         max_depth=None,
#                                                                         max_features='auto',
#                                                                         max_leaf_nodes=None,
#                                                                         max_samples=None,
#                                                                         min_impurity_decrease=0.0,
#                                                                         min_impurity_split=None,
#                                                                         min_samples_leaf=1,
#                                                                         min_samples_split=2,
#                                                                         min_weight_fraction_leaf=0.0,
#                                                                         n_estimators=100,
#                                                                         n_jobs=None,
#                                                                         oob_score=False,
#                                                                         random_state=None,
#                                                                         verbose=0,
#                                                                         warm_start=False),
#                                        n_jobs=None))],
#          verbose=False)

# %%
y_pred = pipe.predict(X_test)

# %%
for col_idx, col in enumerate(output_columns):
    print(f'{col} accuracy \n')
    print(classification_report(y_test[col], y_pred[:, col_idx]))
# Out:
# related accuracy
#
#               precision    recall  f1-score   support
#
#            0       0.73      0.40      0.52      1892
#            1       0.83      0.95      0.89      5899
#            2       0.88      0.12      0.21        58
#
#     accuracy                           0.81      7849
#    macro avg       0.81      0.49      0.54      7849
# weighted avg       0.80      0.81      0.79      7849
#
# request accuracy
#
#               precision    recall  f1-score   support
#
#            0       0.90      0.98      0.94      6522
#            1       0.82      0.49      0.61      1327
#
#     accuracy                           0.89      7849
#    macro avg       0.86      0.73      0.77      7849
# weighted avg       0.89      0.89      0.88      7849
#
# offer accuracy
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      7818
#            1       0.00      0.00      0.00        31
#
#     accuracy                           1.00      7849
#    macro avg       0.50      0.50      0.50      7849
# weighted avg       0.99      1.00      0.99      7849
#
# aid_related accuracy
#
#               precision    recall  f1-score   support
#
#            0       0.80      0.84      0.82      4649
#            1       0.75      0.69      0.72      3200
#
#     accuracy                           0.78      7849
#    macro avg       0.77      0.76      0.77      7849
# weighted avg       0.78      0.78      0.78      7849
#
# medical_help accuracy
#
#               precision    recall  f1-score   support
#
#            0       0.93      1.00      0.96      7240
#            1       0.65      0.09      0.16       609
#
#     accuracy                           0.93      7849
#    macro avg       0.79      0.54      0.56      7849
# weighted avg       0.91      0.93      0.90      7849
#
# medical_products accuracy
#
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98      7476
#            1       0.80      0.11      0.19       373
#
#     accuracy                           0.96      7849
#    macro avg       0.88      0.55      0.59      7849
# weighted avg       0.95      0.96      0.94      7849
#
# search_and_rescue accuracy
#
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.99      7630
#            1       0.78      0.03      0.06       219
#
#     accuracy                           0.97      7849
#    macro avg       0.88      0.52      0.52      7849
# weighted avg       0.97      0.97      0.96      7849
#
# security accuracy
#
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      7709
#            1       0.00      0.00      0.00       140
#
#     accuracy                           0.98      7849
#    macro avg       0.49      0.50      0.50      7849
# weighted avg       0.96      0.98      0.97      7849
#
# military accuracy
#
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98      7583
#            1       0.65      0.06      0.12       266
#
#     accuracy                           0.97      7849
#    macro avg       0.81      0.53      0.55      7849
# weighted avg       0.96      0.97      0.95      7849
#
# child_alone accuracy
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      7849
#
#     accuracy                           1.00      7849
#    macro avg       1.00      1.00      1.00      7849
# weighted avg       1.00      1.00      1.00      7849
#
# water accuracy
#
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98      7364
#            1       0.89      0.36      0.51       485
#
#     accuracy                           0.96      7849
#    macro avg       0.93      0.68      0.75      7849
# weighted avg       0.96      0.96      0.95      7849
#
# food accuracy
#
#               precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97      7000
#            1       0.84      0.61      0.71       849
#
#     accuracy                           0.95      7849
#    macro avg       0.90      0.80      0.84      7849
# weighted avg       0.94      0.95      0.94      7849
#
# shelter accuracy
#
#               precision    recall  f1-score   support
#
#            0       0.94      0.99      0.97      7170
#            1       0.82      0.36      0.50       679
#
#     accuracy                           0.94      7849
#    macro avg       0.88      0.68      0.73      7849
# weighted avg       0.93      0.94      0.93      7849
#
# clothing accuracy
#
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      7737
#            1       0.80      0.14      0.24       112
#
#     accuracy                           0.99      7849
#    macro avg       0.89      0.57      0.62      7849
# weighted avg       0.99      0.99      0.98      7849
#
# money accuracy
#
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      7659
#            1       0.71      0.03      0.05       190
#
#     accuracy                           0.98      7849
#    macro avg       0.85      0.51      0.52      7849
# weighted avg       0.97      0.98      0.97      7849
#
# missing_people accuracy
#
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00      7776
#            1       0.50      0.01      0.03        73
#
#     accuracy                           0.99      7849
#    macro avg       0.75      0.51      0.51      7849
# weighted avg       0.99      0.99      0.99      7849
#
# refugees accuracy
#
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98      7578
#            1       0.46      0.02      0.04       271
#
#     accuracy                           0.97      7849
#    macro avg       0.71      0.51      0.51      7849
# weighted avg       0.95      0.97      0.95      7849
#
# death accuracy
#
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98      7485
#            1       0.84      0.13      0.23       364
#
#     accuracy                           0.96      7849
#    macro avg       0.90      0.57      0.61      7849
# weighted avg       0.95      0.96      0.94      7849
#
# other_aid accuracy
#
#               precision    recall  f1-score   support
#
#            0       0.87      1.00      0.93      6797
#            1       0.69      0.04      0.07      1052
#
#     accuracy                           0.87      7849
#    macro avg       0.78      0.52      0.50      7849
# weighted avg       0.85      0.87      0.81      7849
#
# infrastructure_related accuracy
#
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97      7345
#            1       0.20      0.00      0.00       504
#
#     accuracy                           0.94      7849
#    macro avg       0.57      0.50      0.49      7849
# weighted avg       0.89      0.94      0.90      7849
#
# transport accuracy
#
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98      7495
#            1       0.70      0.08      0.14       354
#
#     accuracy                           0.96      7849
#    macro avg       0.83      0.54      0.56      7849
# weighted avg       0.95      0.96      0.94      7849
#
# buildings accuracy
# /Users/danieldacosta/.virtualenvs/cor/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98      7457
#            1       0.82      0.12      0.21       392
#
#     accuracy                           0.95      7849
#    macro avg       0.89      0.56      0.59      7849
# weighted avg       0.95      0.95      0.94      7849
#
# electricity accuracy
#
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      7694
#            1       1.00      0.03      0.05       155
#
#     accuracy                           0.98      7849
#    macro avg       0.99      0.51      0.52      7849
# weighted avg       0.98      0.98      0.97      7849
#
# tools accuracy
#
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00      7805
#            1       0.00      0.00      0.00        44
#
#     accuracy                           0.99      7849
#    macro avg       0.50      0.50      0.50      7849
# weighted avg       0.99      0.99      0.99      7849
#
# hospitals accuracy
#
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      7764
#            1       0.00      0.00      0.00        85
#
#     accuracy                           0.99      7849
#    macro avg       0.49      0.50      0.50      7849
# weighted avg       0.98      0.99      0.98      7849
#
# shops accuracy
#
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00      7808
#            1       0.00      0.00      0.00        41
#
#     accuracy                           0.99      7849
#    macro avg       0.50      0.50      0.50      7849
# weighted avg       0.99      0.99      0.99      7849
#
# aid_centers accuracy
#
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      7768
#            1       0.00      0.00      0.00        81
#
#     accuracy                           0.99      7849
#    macro avg       0.49      0.50      0.50      7849
# weighted avg       0.98      0.99      0.98      7849
#
# other_infrastructure accuracy
#
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98      7508
#            1       0.00      0.00      0.00       341
#
#     accuracy                           0.96      7849
#    macro avg       0.48      0.50      0.49      7849
# weighted avg       0.91      0.96      0.94      7849
#
# weather_related accuracy
#
#               precision    recall  f1-score   support
#
#            0       0.89      0.95      0.92      5695
#            1       0.83      0.69      0.75      2154
#
#     accuracy                           0.88      7849
#    macro avg       0.86      0.82      0.84      7849
# weighted avg       0.87      0.88      0.87      7849
#
# floods accuracy
#
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.98      7223
#            1       0.89      0.49      0.63       626
#
#     accuracy                           0.95      7849
#    macro avg       0.92      0.74      0.80      7849
# weighted avg       0.95      0.95      0.95      7849
#
# storm accuracy
#
#               precision    recall  f1-score   support
#
#            0       0.96      0.98      0.97      7131
#            1       0.77      0.55      0.64       718
#
#     accuracy                           0.94      7849
#    macro avg       0.86      0.77      0.81      7849
# weighted avg       0.94      0.94      0.94      7849
#
# fire accuracy
#
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      7767
#            1       1.00      0.01      0.02        82
#
#     accuracy                           0.99      7849
#    macro avg       0.99      0.51      0.51      7849
# weighted avg       0.99      0.99      0.98      7849
#
# earthquake accuracy
#
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98      7154
#            1       0.86      0.80      0.83       695
#
#     accuracy                           0.97      7849
#    macro avg       0.92      0.90      0.91      7849
# weighted avg       0.97      0.97      0.97      7849
#
# cold accuracy
#
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      7681
#            1       0.87      0.08      0.14       168
#
#     accuracy                           0.98      7849
#    macro avg       0.92      0.54      0.57      7849
# weighted avg       0.98      0.98      0.97      7849
#
# other_weather accuracy
#
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97      7421
#            1       0.73      0.04      0.07       428
#
#     accuracy                           0.95      7849
#    macro avg       0.84      0.52      0.52      7849
# weighted avg       0.94      0.95      0.92      7849
#
# direct_report accuracy
#
#               precision    recall  f1-score   support
#
#            0       0.87      0.98      0.92      6331
#            1       0.79      0.37      0.50      1518
#
#     accuracy                           0.86      7849
#    macro avg       0.83      0.67      0.71      7849
# weighted avg       0.85      0.86      0.84      7849

# %%
y_pred_train = pipe.predict(X_train)

# %%
for col_idx, col in enumerate(output_columns):
    print(f'{col} accuracy \n')
    print(accuracy_score(y_pred_train[:, col_idx], y_train[col]))
# Out:
# related accuracy
#
# 0.998416425490089
# request accuracy
#
# 0.9992901217714192
# offer accuracy
#
# 0.9998907879648338
# aid_related accuracy
#
# 0.9989078796483373
# medical_help accuracy
#
# 0.9997815759296674
# medical_products accuracy
#
# 0.9998361819472505
# search_and_rescue accuracy
#
# 0.9998361819472505
# security accuracy
#
# 0.9996723638945012
# military accuracy
#
# 0.9998907879648338
# child_alone accuracy
#
# 1.0
# water accuracy
#
# 1.0
# food accuracy
#
# 0.9998907879648338
# shelter accuracy
#
# 0.9998361819472505
# clothing accuracy
#
# 0.9998361819472505
# money accuracy
#
# 0.9999453939824169
# missing_people accuracy
#
# 0.9998361819472505
# refugees accuracy
#
# 0.9998361819472505
# death accuracy
#
# 0.9998361819472505
# other_aid accuracy
#
# 0.9990170916835035
# infrastructure_related accuracy
#
# 0.9997815759296674
# transport accuracy
#
# 0.9996723638945012
# buildings accuracy
#
# 1.0
# electricity accuracy
#
# 0.9998907879648338
# tools accuracy
#
# 0.9999453939824169
# hospitals accuracy
#
# 0.9999453939824169
# shops accuracy
#
# 0.9998907879648338
# aid_centers accuracy
#
# 0.9998907879648338
# other_infrastructure accuracy
#
# 0.9997269699120843
# weather_related accuracy
#
# 0.9995085458417517
# floods accuracy
#
# 0.9997269699120843
# storm accuracy
#
# 0.9999453939824169
# fire accuracy
#
# 1.0
# earthquake accuracy
#
# 0.9996177578769181
# cold accuracy
#
# 0.9998907879648338
# other_weather accuracy
#
# 0.9998907879648338
# direct_report accuracy
#
# 0.999180909736253

# %%
print(classification_report(y_test, y_pred,target_names=my_tags))
